# %%
from classevent import event
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from classevent import event
#
# File C:\HOPE\AI COURSE\PYTHON\classevent.py:59
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 5,
#       6    "id": "f2b8c4e7-a5b4-4b91-9a27-89f2cb5f08e2",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "class event():\n",
#      11     "    def Subfields():\n",
#      12     "        print(\"Sub-fields in AI are:\")\n",
#      13     "        ai=[\"Machine Learing\",\"Neural Networks\",\"Vision\",\"Robotics\",\"Speech Processing\",\"Natural Language processing\"]\n",
#      14     "        for i in ai:\n",
#      15     "            print(i)\n",
#      16     "    def OddEven():\n",
#      17     "        num=int(input(\"Enter a number:\"))\n",
# ...
